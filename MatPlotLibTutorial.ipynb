# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
#set size of plots
plt.rc('figure',figsize=(15,8))

# %%
fig=plt.figure()
axes=plt.axes()
x_data = np.linspace(start=0,stop=10,num=1000)
output = axes.plot( x_data,np.sin(x))

# %%
plt.plot(x_data,np.cos(x_data), label="cos")
plt.plot(x_data,np.sin(x_data), label="sin")
plt.plot(x_data,np.cos(x_data+1),color='black', linestyle='dashed')
plt.xlim(left=0,right=10)
plt.title(label='My First Plot')
plt.xlabel(xlabel='x')
plt.ylabel(ylabel='y values')
# Out:
#   File "<ipython-input-30-c67bcad6615e>", line 8
#     plt.
#         ^
# SyntaxError: invalid syntax

# %%
x_small= np.linspace(start=0,stop=10,num=1000)
plt.plot(x_small, np.sin(x_small))

# %%
x_scatter=np.random.rand(100)
y_scatter=np.random.rand(100)
plt.scatter(x_scatter,y_scatter)

# %%
#plt.scatter(x_scatter,y_scatter,s=100*np.random.rand(100))
sizes=100*np.random.rand(100)
colors = np.random.rand(100)
plt.scatter(x_scatter,y_scatter,c=colors,s=sizes, cmap='viridis')
plt.colorbar()

# %%
for colors in colors:
  print(colors)

# %%
x_bar = np.random.rand(100)
plt.hist(x_bar)
# Out:
# (array([14.,  8.,  9., 11.,  8., 11., 15.,  9.,  8.,  7.]),
#  array([0.00441122, 0.10260681, 0.2008024 , 0.29899799, 0.39719357,
#         0.49538916, 0.59358475, 0.69178033, 0.78997592, 0.88817151,
#         0.9863671 ]),
#  <a list of 10 Patch objects>)

# %%
x_bar = np.random.randn(100)
plt.hist(x_bar, bins=5,density=True , alpha= 0.25, color='black')
# Out:
# (array([0.04967876, 0.24129682, 0.31226647, 0.09935751, 0.00709697]),
#  array([-2.87656359, -1.46751063, -0.05845767,  1.35059529,  2.75964825,
#          4.16870121]),
#  <a list of 5 Patch objects>)

# %%
plt.subplot(1,3,1)
plt.plot(x_small, np.cos(x_small))
plt.subplot(1,3,2)
plt.plot(x_small, np.sin(x_small))
plt.subplot(1,3,3)
plt.plot(x_small, np.tan(x_small))

# %%
fig, axes =plt.subplots(1,3,sharey='row')
plt.subplot(1,3,1)
plt.plot(x_small,np.sin(x_small))
